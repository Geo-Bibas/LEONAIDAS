# %%
from pyspark.sql import SparkSession

warehouse_path = "file:///C:/tmp/spark_warehouse"
postgres_driver_path = "C:\postgresql-42.7.5.jar"

# Initialize SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Hudi Batch Write") \
    .config("spark.jars.packages", "org.apache.hudi:hudi-spark3.3-bundle_2.12:0.14.0") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .config("spark.sql.hive.convertMetastoreParquet", "false") \
    .config("spark.sql.extensions", "org.apache.spark.sql.hudi.HoodieSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.hudi.catalog.HoodieCatalog") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.executor.memoryOverhead", "1g") \
    .config("spark.driver.memoryOverhead", "1g") \
    .config("spark.sql.warehouse.dir", warehouse_path) \
    .getOrCreate()

# Now you can read the Hudi table
read_df = spark.read \
    .format("hudi") \
    .load(f"{warehouse_path}/from_kafka")  # double check the path

# Show the contents
read_df.show()

# Optional: You can also perform queries on the data
# For example, to get total records:
print(f"Total records: {read_df.count()}")

# Or to see the schema:
read_df.printSchema()
# Out:
# +-------------------+--------------------+------------------+----------------------+--------------------+------+--------+----------+--------------------+-----+-------------+------------------+------+----------------+---------+--------------------+-----+---------+----------+---------------+-----------+------------+------+-------------+--------------------+----------+----------------+----------+--------------------+----------+
# |_hoodie_commit_time|_hoodie_commit_seqno|_hoodie_record_key|_hoodie_partition_path|   _hoodie_file_name|    id|semester|      code|         description|units|instructor_id|   instructor_name|srcode|        fullname|   campus|             program|major|yearlevel|curriculum|  class_section|grade_final|grade_reexam|status|grade_numeric|grade_classification|start_year|        year_sem|program_id|     processing_time|schoolyear|
# +-------------------+--------------------+------------------+----------------------+--------------------+------+--------+----------+--------------------+-----+-------------+------------------+------+----------------+---------+--------------------+-----+---------+----------+---------------+-----------+------------+------+-------------+--------------------+----------+----------------+----------+--------------------+----------+
# |  20250328164401721|20250328164401721...|            122477|             2023-2024|ca793989-2663-40e...|122477|  SUMMER|   GEd 103|Life and Works of...|    3|       -13692|LN-13692, FN-13692| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1301|       1.50|        null|PASSED|         1.50|              NORMAL|      2023|2023-2024-SUMMER|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122486|             2023-2024|ca793989-2663-40e...|122486|   FIRST|NSTP 111RO|NSTP - Reserve Of...|    3|       -13239|LN-13239, FN-13239| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|NSTP111RO-AL-04|       2.00|        null|PASSED|         2.00|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122475|             2023-2024|ca793989-2663-40e...|122475|  SECOND| PATHFit 2|Exercise-Based Fi...|    2|       -13659|LN-13659, FN-13659| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1201|       1.50|        null|PASSED|         1.50|              NORMAL|      2023|2023-2024-SECOND|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122484|             2023-2024|ca793989-2663-40e...|122484|   FIRST|   GEd 106|Purposive Communi...|    3|       -11854|LN-11854, FN-11854| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1101|       1.50|        null|PASSED|         1.50|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122488|             2023-2024|ca793989-2663-40e...|122488|   FIRST|   SCI 401|   General Chemistry|    4|       -11984|LN-11984, FN-11984| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1101|       1.75|        null|PASSED|         1.75|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122471|             2023-2024|ca793989-2663-40e...|122471|  SECOND|   GEd 108|    Art Appreciation|    3|       -12773|LN-12773, FN-12773| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1201|       1.75|        null|PASSED|         1.75|              NORMAL|      2023|2023-2024-SECOND|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122479|             2023-2024|ca793989-2663-40e...|122479|  SUMMER|   SCI 402|      Modern Biology|    3|       -13488|LN-13488, FN-13488| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1301|       1.50|        null|PASSED|         1.50|              NORMAL|      2023|2023-2024-SUMMER|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122480|             2023-2024|ca793989-2663-40e...|122480|   FIRST|  ENGG 401|Introduction to E...|    1|       -10290|LN-10290, FN-10290| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1101|       1.25|        null|PASSED|         1.25|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122473|             2023-2024|ca793989-2663-40e...|122473|  SECOND|  MATH 402|   Integral Calculus|    3|       -12417|LN-12417, FN-12417| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1201|       1.25|        null|PASSED|         1.25|              NORMAL|      2023|2023-2024-SECOND|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122468|             2023-2024|ca793989-2663-40e...|122468|  SECOND|   CpE 401|Computer Programm...|    1|       -10562|LN-10562, FN-10562| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1201|       1.50|        null|PASSED|         1.50|              NORMAL|      2023|2023-2024-SECOND|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122482|             2023-2024|ca793989-2663-40e...|122482|   FIRST|   GEd 102|Mathematics in th...|    3|       -12802|LN-12802, FN-12802| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1101|       2.50|        null|PASSED|         2.50|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122472|             2023-2024|ca793989-2663-40e...|122472|  SECOND|   GEd 109|Science, Technolo...|    3|       -11556|LN-11556, FN-11556| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1201|       1.75|        null|PASSED|         1.75|              NORMAL|      2023|2023-2024-SECOND|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122487|             2023-2024|ca793989-2663-40e...|122487|   FIRST| PATHFit 1|Movement Competen...|    2|       -13659|LN-13659, FN-13659| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1101|       1.50|        null|PASSED|         1.50|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122469|             2023-2024|ca793989-2663-40e...|122469|  SECOND|  ENGG 402| Engineering Drawing|    1|       -10488|LN-10488, FN-10488| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1201|       1.50|        null|PASSED|         1.50|              NORMAL|      2023|2023-2024-SECOND|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122485|             2023-2024|ca793989-2663-40e...|122485|   FIRST|  MATH 401|Differential Calc...|    3|       -13877|LN-13877, FN-13877| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1101|       3.00|        null|PASSED|         3.00|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122474|             2023-2024|ca793989-2663-40e...|122474|  SECOND|NSTP 121RO|NSTP - Reserve Of...|    3|       -13239|LN-13239, FN-13239| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|NSTP121RO-AL-05|       1.50|        null|PASSED|         1.50|              NORMAL|      2023|2023-2024-SECOND|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122478|             2023-2024|ca793989-2663-40e...|122478|  SUMMER|   GEd 107|              Ethics|    3|       -12044|LN-12044, FN-12044| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1301|       1.25|        null|PASSED|         1.25|              NORMAL|      2023|2023-2024-SUMMER|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122481|             2023-2024|ca793989-2663-40e...|122481|   FIRST|   GEd 101|Understanding the...|    3|       -12773|LN-12773, FN-12773| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1101|       1.75|        null|PASSED|         1.75|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122470|             2023-2024|ca793989-2663-40e...|122470|  SECOND|   GEd 104|The Contemporary ...|    3|       -12044|LN-12044, FN-12044| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1201|       2.25|        null|PASSED|         2.25|              NORMAL|      2023|2023-2024-SECOND|        59|2025-03-28 16:44:...| 2023-2024|
# |  20250328164401721|20250328164401721...|            122483|             2023-2024|ca793989-2663-40e...|122483|   FIRST|   GEd 105|Readings in Phili...|    3|       -13692|LN-13692, FN-13692| 23255|LN23255, FN23255|ALANGILAN|BS Mechatronics E...| null|    FIRST| 2023-2024|      MEXE-1101|       1.50|        null|PASSED|         1.50|              NORMAL|      2023| 2023-2024-FIRST|        59|2025-03-28 16:44:...| 2023-2024|
# +-------------------+--------------------+------------------+----------------------+--------------------+------+--------+----------+--------------------+-----+-------------+------------------+------+----------------+---------+--------------------+-----+---------+----------+---------------+-----------+------------+------+-------------+--------------------+----------+----------------+----------+--------------------+----------+
# only showing top 20 rows
#
# Total records: 282
# root
#  |-- _hoodie_commit_time: string (nullable = true)
#  |-- _hoodie_commit_seqno: string (nullable = true)
#  |-- _hoodie_record_key: string (nullable = true)
#  |-- _hoodie_partition_path: string (nullable = true)
#  |-- _hoodie_file_name: string (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- semester: string (nullable = true)
#  |-- code: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- units: integer (nullable = true)
#  |-- instructor_id: string (nullable = true)
#  |-- instructor_name: string (nullable = true)
#  |-- srcode: string (nullable = true)
#  |-- fullname: string (nullable = true)
#  |-- campus: string (nullable = true)
#  |-- program: string (nullable = true)
#  |-- major: string (nullable = true)
#  |-- yearlevel: string (nullable = true)
#  |-- curriculum: string (nullable = true)
#  |-- class_section: string (nullable = true)
#  |-- grade_final: string (nullable = true)
#  |-- grade_reexam: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- grade_numeric: decimal(5,2) (nullable = true)
#  |-- grade_classification: string (nullable = false)
#  |-- start_year: integer (nullable = true)
#  |-- year_sem: string (nullable = false)
#  |-- program_id: integer (nullable = true)
#  |-- processing_time: timestamp (nullable = false)
#  |-- schoolyear: string (nullable = true)
