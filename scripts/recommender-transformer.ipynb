# %%
from pyspark.sql import SparkSession

warehouse_path = "file:///C:/tmp/spark_warehouse"

jdbc_url = "jdbc:postgresql://192.168.20.11:5432/caist_db_v2"
#jdbc_url = "jdbc:postgresql://localhost:5432/local_student_grades"
properties = {
    "user": "postgres", 
    "password": "postgres",  
    "driver": "org.postgresql.Driver",
    "fetchsize": "10000"
}

#DOWNLOAD FROM ORACLE
postgres_driver_path = "C:\postgresql-42.7.5.jar"

def extract(jdbc_url, table_name, properties, postgres_driver_path):
    """ Extract data from PostgreSQL database using Spark."""
    # Initialize Spark session
    # Initialize Spark session
    spark = SparkSession.builder \
        .master("local[*]") \
        .appName("Hudi Batch Write") \
        .config("spark.jars", postgres_driver_path) \
        .config("spark.jars.packages", "org.apache.hudi:hudi-spark3.3-bundle_2.12:0.14.0") \
        .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
        .config("spark.sql.hive.convertMetastoreParquet", "false") \
        .config("spark.sql.extensions", "org.apache.spark.sql.hudi.HoodieSparkSessionExtension") \
        .config("spark.driver.memory", "4g") \
        .config("spark.executor.memory", "4g") \
        .config("spark.executor.memoryOverhead", "1g") \
        .config("spark.driver.memoryOverhead", "1g") \
        .config("spark.sql.warehouse.dir", warehouse_path) \
        .getOrCreate()

    # Extracts data from PostgreSQL database
    df = spark.read.jdbc(
        url=jdbc_url,
        table=table_name,
        properties=properties,
    )
    
    return df, spark

# Extract data once
raw_df, spark = extract(jdbc_url, "processed_grades", properties, postgres_driver_path)

# Check the number of rows
row_count = raw_df.count()
print(f'Number of rows: {row_count}')

# Print schema
raw_df.printSchema()
# Out:
# Number of rows: 1998648
# root
#  |-- id: integer (nullable = true)
#  |-- schoolyear: string (nullable = true)
#  |-- semester: string (nullable = true)
#  |-- code: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- units: integer (nullable = true)
#  |-- instructor_id: string (nullable = true)
#  |-- instructor_name: string (nullable = true)
#  |-- srcode: string (nullable = true)
#  |-- fullname: string (nullable = true)
#  |-- campus: string (nullable = true)
#  |-- program: string (nullable = true)
#  |-- major: string (nullable = true)
#  |-- yearlevel: string (nullable = true)
#  |-- curriculum: string (nullable = true)
#  |-- class_section: string (nullable = true)
#  |-- grade_final: string (nullable = true)
#  |-- grade_reexam: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- grade_numeric: decimal(10,2) (nullable = true)
#  |-- grade_classification: string (nullable = true)
#  |-- start_year: integer (nullable = true)
#  |-- year_sem: string (nullable = true)
#  |-- program_id: integer (nullable = true)

# %%
raw_df.show()
# Out:
# +------+----------+--------+----------+--------------------+-----+-------------+------------------+------+----------------+------+--------------------+-------+---------+----------+---------------+-----------+------------+------+-------------+--------------------+----------+----------------+----------+
# |    id|schoolyear|semester|      code|         description|units|instructor_id|   instructor_name|srcode|        fullname|campus|             program|  major|yearlevel|curriculum|  class_section|grade_final|grade_reexam|status|grade_numeric|grade_classification|start_year|        year_sem|program_id|
# +------+----------+--------+----------+--------------------+-----+-------------+------------------+------+----------------+------+--------------------+-------+---------+----------+---------------+-----------+------------+------+-------------+--------------------+----------+----------------+----------+
# |801712| 2023-2024|  SECOND|  Fili 102|Filipino sa Iba't...|    3|       -11078|LN-11078, FN-11078| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|   SECOND| 2018-2019|  BSED-ENG-2201|       2.50|        null|PASSED|         2.50|              NORMAL|      2023|2023-2024-SECOND|        20|
# |801713| 2023-2024|  SECOND|   GEd 109|Science, Technolo...|    3|       -12086|LN-12086, FN-12086| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|   SECOND| 2018-2019|  BSED-ENG-2201|       2.50|        null|PASSED|         2.50|              NORMAL|      2023|2023-2024-SECOND|        20|
# |801714| 2023-2024|  SECOND|    PE 104|         Team Sports|    2|       -12655|LN-12655, FN-12655| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|   SECOND| 2018-2019|  BSED-ENG-2201|       1.50|        null|PASSED|         1.50|              NORMAL|      2023|2023-2024-SECOND|        20|
# |801715| 2024-2025|   FIRST|    Ed 109|Assessment in Lea...|    3|       -12008|LN-12008, FN-12008| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    THIRD| 2018-2019|  BSED-ENG-3101|       2.50|        null|PASSED|         2.50|              NORMAL|      2024| 2024-2025-FIRST|        20|
# |801716| 2024-2025|   FIRST|    Ed 110|Building and Enha...|    3|       -10987|LN-10987, FN-10987| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    THIRD| 2018-2019|  BSED-ENG-3101|       1.75|        null|PASSED|         1.75|              NORMAL|      2024| 2024-2025-FIRST|        20|
# |801717| 2024-2025|   FIRST|   EEd 311|Survey of Philipp...|    3|       -13560|LN-13560, FN-13560| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    THIRD| 2018-2019|  BSED-ENG-3101|       2.00|        null|PASSED|         2.00|              NORMAL|      2024| 2024-2025-FIRST|        20|
# |801718| 2024-2025|   FIRST|   EEd 312|Survey of Afro-As...|    3|       -10492|LN-10492, FN-10492| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    THIRD| 2018-2019|  BSED-ENG-3101|       2.50|        null|PASSED|         2.50|              NORMAL|      2024| 2024-2025-FIRST|        20|
# |801719| 2024-2025|   FIRST|   EEd 313|Survey of English...|    3|       -12576|LN-12576, FN-12576| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    THIRD| 2018-2019|  BSED-ENG-3101|       2.00|        null|PASSED|         2.00|              NORMAL|      2024| 2024-2025-FIRST|        20|
# |801720| 2024-2025|   FIRST|   EEd 314|Language Learning...|    3|       -11476|LN-11476, FN-11476| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    THIRD| 2018-2019|  BSED-ENG-3101|       2.00|        null|PASSED|         2.00|              NORMAL|      2024| 2024-2025-FIRST|        20|
# |801721| 2024-2025|   FIRST|   EEd 315|Research in Engli...|    3|       -11072|LN-11072, FN-11072| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    THIRD| 2018-2019|  BSED-ENG-3101|       2.00|        null|PASSED|         2.00|              NORMAL|      2024| 2024-2025-FIRST|        20|
# |801722| 2024-2025|   FIRST|  Fili 103|Retorika - Masini...|    3|       -11077|LN-11077, FN-11077| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    THIRD| 2018-2019|  BSED-ENG-3101|       2.25|        null|PASSED|         2.25|              NORMAL|      2024| 2024-2025-FIRST|        20|
# |801723| 2022-2023|   FIRST|    Ed 101|The Child and Ado...|    3|       -10692|LN-10692, FN-10692| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|  BSED-ENG-1101|       2.75|        null|PASSED|         2.75|              NORMAL|      2022| 2022-2023-FIRST|        20|
# |801724| 2022-2023|   FIRST|   EEd 111|Introduction to L...|    3|       -13560|LN-13560, FN-13560| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|  BSED-ENG-1101|       2.75|        null|PASSED|         2.75|              NORMAL|      2022| 2022-2023-FIRST|        20|
# |801725| 2022-2023|   FIRST|   EEd 112|Language, Culture...|    3|       -11077|LN-11077, FN-11077| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|  BSED-ENG-1101|       3.00|        null|PASSED|         3.00|              NORMAL|      2022| 2022-2023-FIRST|        20|
# |801726| 2022-2023|   FIRST|   EEd 113|Structure of English|    3|       -10929|LN-10929, FN-10929| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|  BSED-ENG-1101|       3.00|        null|PASSED|         3.00|              NORMAL|      2022| 2022-2023-FIRST|        20|
# |801727| 2022-2023|   FIRST|  Fili 101|Kontekstwalisadon...|    3|       -10892|LN-10892, FN-10892| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|  BSED-ENG-1101|       2.75|        null|PASSED|         2.75|              NORMAL|      2022| 2022-2023-FIRST|        20|
# |801728| 2022-2023|   FIRST|   GEd 101|Understanding the...|    3|       -10337|LN-10337, FN-10337| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|  BSED-ENG-1101|       2.50|        null|PASSED|         2.50|              NORMAL|      2022| 2022-2023-FIRST|        20|
# |801729| 2022-2023|   FIRST|   GEd 102|Mathematics in th...|    3|       -13304|LN-13304, FN-13304| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|  BSED-ENG-1101|       3.00|        null|PASSED|         3.00|              NORMAL|      2022| 2022-2023-FIRST|        20|
# |801730| 2022-2023|   FIRST|   GEd 103|Life and Works of...|    3|       -12218|LN-12218, FN-12218| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|  BSED-ENG-1101|       1.50|        null|PASSED|         1.50|              NORMAL|      2022| 2022-2023-FIRST|        20|
# |801731| 2022-2023|   FIRST|NSTP 111LT|NSTP - Literacy T...|    3|       -10669|LN-10669, FN-10669| 43122|LN43122, FN43122|    PB|Bachelor of Secon...|English|    FIRST| 2018-2019|NSTP111LT-MA-01|       1.50|        null|PASSED|         1.50|              NORMAL|      2022| 2022-2023-FIRST|        20|
# +------+----------+--------+----------+--------------------+-----+-------------+------------------+------+----------------+------+--------------------+-------+---------+----------+---------------+-----------+------------+------+-------------+--------------------+----------+----------------+----------+
# only showing top 20 rows

# %%
import json
from pyspark.sql.functions import explode, col

# First, let's read and process the course-career mapping
def get_course_career_mapping(json_str):
    data = json.loads(json_str)
    mapping = {}
    for course in data['courses']:
        mapping[course['course']] = course['careers']
    return mapping

# Create function to transform the dataframe
def map_courses_to_careers(df, course_career_mapping):
    # Convert mapping to a list of (course, career) pairs
    mapping_pairs = []
    for course, careers in course_career_mapping.items():
        for career in careers:
            mapping_pairs.append((course, career))
            
    # Create a mapping DataFrame
    mapping_df = spark.createDataFrame(mapping_pairs, ["description", "career"])
    
    # Join with original dataframe and select required columns
    result_df = df.join(mapping_df, "description", "inner") \
                  .select("srcode", "description", "grade_numeric", "career")
    
    return result_df

# Read the JSON file
with open("C:/LEONAIDAS/scripts/career-mapping/BS Information Technology.json", "r") as f:
    course_career_json = f.read()

# Now you can use the rest of your code as is
mapping = get_course_career_mapping(course_career_json)

# Apply the transformation to your raw_df
result_df = map_courses_to_careers(raw_df, mapping)

# Show the results
result_df = result_df.orderBy("srcode", "description")

result_df.show(50, truncate=False)
# Out:
# +------+------------------------------+-------------+-----------------------------------------------+
# |srcode|description                   |grade_numeric|career                                         |
# +------+------------------------------+-------------+-----------------------------------------------+
# |20006 |Business Communication        |1.50         |BPO Specialist/Analyst                         |
# |20006 |Business Communication        |1.50         |Technical Writer                               |
# |20006 |Business Communication        |1.50         |BPO Team Leader/Manager                        |
# |20006 |Business Communication        |1.50         |IT Consultant                                  |
# |20006 |Service Culture               |2.75         |BPO Specialist/Analyst                         |
# |20006 |Service Culture               |2.75         |BPO Team Leader/Manager                        |
# |20006 |Service Culture               |2.75         |Help Desk/Technical Support Specialist         |
# |20007 |Computer Programming 1        |2.00         |Game Developer                                 |
# |20007 |Computer Programming 1        |2.00         |Applications Developer                         |
# |20007 |Computer Programming 1        |2.00         |Software Engineer                              |
# |20007 |Computer Programming 1        |2.00         |Web Developer (Front-End, Back-End, Full-Stack)|
# |20007 |Computer Programming 1        |2.00         |Mobile App Developer                           |
# |20007 |Computer Programming 1        |2.00         |Data Scientist                                 |
# |20010 |Advanced Computer Programming |2.25         |Data Scientist                                 |
# |20010 |Advanced Computer Programming |2.25         |Applications Developer                         |
# |20010 |Advanced Computer Programming |2.25         |Game Developer                                 |
# |20010 |Advanced Computer Programming |2.25         |Software Engineer                              |
# |20010 |Computer Networking 1         |1.50         |Cybersecurity Analyst/Engineer                 |
# |20010 |Computer Networking 1         |1.50         |Network Administrator                          |
# |20010 |Computer Programming          |2.25         |Game Developer                                 |
# |20010 |Computer Programming          |2.25         |Web Developer (Front-End, Back-End, Full-Stack)|
# |20010 |Computer Programming          |2.25         |Mobile App Developer                           |
# |20010 |Computer Programming          |2.25         |Applications Developer                         |
# |20010 |Computer Programming          |2.25         |Software Engineer                              |
# |20010 |Data Structures and Algorithms|1.25         |Software Engineer                              |
# |20010 |Data Structures and Algorithms|1.25         |Game Developer                                 |
# |20010 |Data Structures and Algorithms|1.25         |Data Scientist                                 |
# |20010 |Database Management System    |1.75         |Database Developer/Administrator               |
# |20010 |Database Management System    |1.75         |Data Analyst                                   |
# |20010 |Database Management System    |1.75         |Data Scientist                                 |
# |20010 |Discrete Mathematics          |3.00         |Software Engineer                              |
# |20010 |Discrete Mathematics          |3.00         |Data Scientist                                 |
# |20010 |Introduction to Computing     |1.50         |Applications Developer                         |
# |20010 |Introduction to Computing     |1.50         |Help Desk/Technical Support Specialist         |
# |20010 |Object-Oriented Programming   |2.25         |Game Developer                                 |
# |20010 |Object-Oriented Programming   |2.25         |Applications Developer                         |
# |20010 |Object-Oriented Programming   |2.25         |Software Engineer                              |
# |20010 |Object-Oriented Programming   |2.25         |Mobile App Developer                           |
# |20012 |Computer Programming 1        |1.50         |Web Developer (Front-End, Back-End, Full-Stack)|
# |20012 |Computer Programming 1        |1.50         |Game Developer                                 |
# |20012 |Computer Programming 1        |1.50         |Mobile App Developer                           |
# |20012 |Computer Programming 1        |1.50         |Applications Developer                         |
# |20012 |Computer Programming 1        |1.50         |Software Engineer                              |
# |20012 |Computer Programming 1        |1.50         |Data Scientist                                 |
# |20012 |Computer Programming 2        |1.50         |Data Scientist                                 |
# |20012 |Computer Programming 2        |1.50         |Mobile App Developer                           |
# |20012 |Computer Programming 2        |1.50         |Web Developer (Front-End, Back-End, Full-Stack)|
# |20012 |Computer Programming 2        |1.50         |Software Engineer                              |
# |20012 |Computer Programming 2        |1.50         |Applications Developer                         |
# |20012 |Computer Programming 2        |1.50         |Game Developer                                 |
# +------+------------------------------+-------------+-----------------------------------------------+
# only showing top 50 rows

# %%
# Import required functions
from pyspark.sql.functions import current_timestamp, monotonically_increasing_id

# Add a timestamp column for Hudi
#persem_df = persem_df.withColumn("ts", current_timestamp())

# Generate a unique identifier
result_df = result_df.withColumn("uuid", monotonically_increasing_id())
result_df.show(50, truncate=False)
# Out:
# +------+------------------------------+-------------+-----------------------------------------------+----+
# |srcode|description                   |grade_numeric|career                                         |uuid|
# +------+------------------------------+-------------+-----------------------------------------------+----+
# |20006 |Business Communication        |1.50         |Technical Writer                               |0   |
# |20006 |Business Communication        |1.50         |IT Consultant                                  |1   |
# |20006 |Business Communication        |1.50         |BPO Specialist/Analyst                         |2   |
# |20006 |Business Communication        |1.50         |BPO Team Leader/Manager                        |3   |
# |20006 |Service Culture               |2.75         |Help Desk/Technical Support Specialist         |4   |
# |20006 |Service Culture               |2.75         |BPO Specialist/Analyst                         |5   |
# |20006 |Service Culture               |2.75         |BPO Team Leader/Manager                        |6   |
# |20007 |Computer Programming 1        |2.00         |Data Scientist                                 |7   |
# |20007 |Computer Programming 1        |2.00         |Mobile App Developer                           |8   |
# |20007 |Computer Programming 1        |2.00         |Game Developer                                 |9   |
# |20007 |Computer Programming 1        |2.00         |Software Engineer                              |10  |
# |20007 |Computer Programming 1        |2.00         |Web Developer (Front-End, Back-End, Full-Stack)|11  |
# |20007 |Computer Programming 1        |2.00         |Applications Developer                         |12  |
# |20010 |Advanced Computer Programming |2.25         |Data Scientist                                 |13  |
# |20010 |Advanced Computer Programming |2.25         |Game Developer                                 |14  |
# |20010 |Advanced Computer Programming |2.25         |Software Engineer                              |15  |
# |20010 |Advanced Computer Programming |2.25         |Applications Developer                         |16  |
# |20010 |Computer Networking 1         |1.50         |Cybersecurity Analyst/Engineer                 |17  |
# |20010 |Computer Networking 1         |1.50         |Network Administrator                          |18  |
# |20010 |Computer Programming          |2.25         |Mobile App Developer                           |19  |
# |20010 |Computer Programming          |2.25         |Game Developer                                 |20  |
# |20010 |Computer Programming          |2.25         |Software Engineer                              |21  |
# |20010 |Computer Programming          |2.25         |Web Developer (Front-End, Back-End, Full-Stack)|22  |
# |20010 |Computer Programming          |2.25         |Applications Developer                         |23  |
# |20010 |Data Structures and Algorithms|1.25         |Game Developer                                 |24  |
# |20010 |Data Structures and Algorithms|1.25         |Data Scientist                                 |25  |
# |20010 |Data Structures and Algorithms|1.25         |Software Engineer                              |26  |
# |20010 |Database Management System    |1.75         |Data Scientist                                 |27  |
# |20010 |Database Management System    |1.75         |Data Analyst                                   |28  |
# |20010 |Database Management System    |1.75         |Database Developer/Administrator               |29  |
# |20010 |Discrete Mathematics          |3.00         |Software Engineer                              |30  |
# |20010 |Discrete Mathematics          |3.00         |Data Scientist                                 |31  |
# |20010 |Introduction to Computing     |1.50         |Help Desk/Technical Support Specialist         |32  |
# |20010 |Introduction to Computing     |1.50         |Applications Developer                         |33  |
# |20010 |Object-Oriented Programming   |2.25         |Mobile App Developer                           |34  |
# |20010 |Object-Oriented Programming   |2.25         |Game Developer                                 |35  |
# |20010 |Object-Oriented Programming   |2.25         |Software Engineer                              |36  |
# |20010 |Object-Oriented Programming   |2.25         |Applications Developer                         |37  |
# |20012 |Computer Programming 1        |1.50         |Data Scientist                                 |38  |
# |20012 |Computer Programming 1        |1.50         |Mobile App Developer                           |39  |
# |20012 |Computer Programming 1        |1.50         |Game Developer                                 |40  |
# |20012 |Computer Programming 1        |1.50         |Software Engineer                              |41  |
# |20012 |Computer Programming 1        |1.50         |Web Developer (Front-End, Back-End, Full-Stack)|42  |
# |20012 |Computer Programming 1        |1.50         |Applications Developer                         |43  |
# |20012 |Computer Programming 2        |1.50         |Data Scientist                                 |44  |
# |20012 |Computer Programming 2        |1.50         |Mobile App Developer                           |45  |
# |20012 |Computer Programming 2        |1.50         |Game Developer                                 |46  |
# |20012 |Computer Programming 2        |1.50         |Software Engineer                              |47  |
# |20012 |Computer Programming 2        |1.50         |Web Developer (Front-End, Back-End, Full-Stack)|48  |
# |20012 |Computer Programming 2        |1.50         |Applications Developer                         |49  |
# +------+------------------------------+-------------+-----------------------------------------------+----+
# only showing top 50 rows

# %%
# Import required functions
db_name = "recommender_db"
table_name = "BSIT_recommender"
path = f"{warehouse_path}/{db_name}/{table_name}"

# Define Hudi write options
hudi_options = {
    "hoodie.table.name": f"{table_name}",
    "hoodie.datasource.write.recordkey.field": "uuid",  
    'hoodie.datasource.write.operation': 'bulk_insert',
    "hoodie.datasource.write.keygenerator.class": "org.apache.hudi.keygen.NonpartitionedKeyGenerator"
}

result_df.write.format("hudi") \
    .options(**hudi_options) \
    .mode("overwrite") \
    .save(path)

# %%
# Read the Hudi table
read_df = spark.read \
    .format("hudi") \
    .load(f"{warehouse_path}/recommender_db/BSIT_recommender")

# Show the contents
read_df.show()

# Optional: You can also perform queries on the data
# For example, to get total records:
print(f"Total records: {read_df.count()}")

# Or to see the schema:
read_df.printSchema()
# Out:
# +-------------------+--------------------+------------------+----------------------+--------------------+------+--------------------+-------------+--------------------+-----------+
# |_hoodie_commit_time|_hoodie_commit_seqno|_hoodie_record_key|_hoodie_partition_path|   _hoodie_file_name|srcode|         description|grade_numeric|              career|       uuid|
# +-------------------+--------------------+------------------+----------------------+--------------------+------+--------------------+-------------+--------------------+-----------+
# |  20250319112634102|20250319112634102...|       25769803776|                      |30e3814c-0374-463...| 63543|Computer Programm...|         1.25|      Data Scientist|25769803776|
# |  20250319112634102|20250319112634102...|       25769803777|                      |30e3814c-0374-463...| 63543|Computer Programm...|         1.25|Mobile App Developer|25769803777|
# |  20250319112634102|20250319112634102...|       25769803778|                      |30e3814c-0374-463...| 63543|Computer Programm...|         1.25|      Game Developer|25769803778|
# |  20250319112634102|20250319112634102...|       25769803779|                      |30e3814c-0374-463...| 63543|Computer Programm...|         1.25|   Software Engineer|25769803779|
# |  20250319112634102|20250319112634102...|       25769803780|                      |30e3814c-0374-463...| 63543|Computer Programm...|         1.25|Web Developer (Fr...|25769803780|
# |  20250319112634102|20250319112634102...|       25769803781|                      |30e3814c-0374-463...| 63543|Computer Programm...|         1.25|Applications Deve...|25769803781|
# |  20250319112634102|20250319112634102...|       25769803782|                      |30e3814c-0374-463...| 63546|Computer Programming|         2.00|Mobile App Developer|25769803782|
# |  20250319112634102|20250319112634102...|       25769803783|                      |30e3814c-0374-463...| 63546|Computer Programming|         2.00|      Game Developer|25769803783|
# |  20250319112634102|20250319112634102...|       25769803784|                      |30e3814c-0374-463...| 63546|Computer Programming|         2.00|   Software Engineer|25769803784|
# |  20250319112634102|20250319112634102...|       25769803785|                      |30e3814c-0374-463...| 63546|Computer Programming|         2.00|Web Developer (Fr...|25769803785|
# |  20250319112634102|20250319112634102...|       25769803786|                      |30e3814c-0374-463...| 63546|Computer Programming|         2.00|Applications Deve...|25769803786|
# |  20250319112634102|20250319112634102...|       25769803787|                      |30e3814c-0374-463...| 63546|   Technopreneurship|         1.25|       Technopreneur|25769803787|
# |  20250319112634102|20250319112634102...|       25769803788|                      |30e3814c-0374-463...| 63548|Computer Programm...|         1.75|      Data Scientist|25769803788|
# |  20250319112634102|20250319112634102...|       25769803789|                      |30e3814c-0374-463...| 63548|Computer Programm...|         1.75|Mobile App Developer|25769803789|
# |  20250319112634102|20250319112634102...|       25769803790|                      |30e3814c-0374-463...| 63548|Computer Programm...|         1.75|      Game Developer|25769803790|
# |  20250319112634102|20250319112634102...|       25769803791|                      |30e3814c-0374-463...| 63548|Computer Programm...|         1.75|   Software Engineer|25769803791|
# |  20250319112634102|20250319112634102...|       25769803792|                      |30e3814c-0374-463...| 63548|Computer Programm...|         1.75|Web Developer (Fr...|25769803792|
# |  20250319112634102|20250319112634102...|       25769803793|                      |30e3814c-0374-463...| 63548|Computer Programm...|         1.75|Applications Deve...|25769803793|
# |  20250319112634102|20250319112634102...|       25769803794|                      |30e3814c-0374-463...| 63548|Computer Programm...|         1.50|      Data Scientist|25769803794|
# |  20250319112634102|20250319112634102...|       25769803795|                      |30e3814c-0374-463...| 63548|Computer Programm...|         1.50|Mobile App Developer|25769803795|
# +-------------------+--------------------+------------------+----------------------+--------------------+------+--------------------+-------------+--------------------+-----------+
# only showing top 20 rows
#
# Total records: 262058
# root
#  |-- _hoodie_commit_time: string (nullable = true)
#  |-- _hoodie_commit_seqno: string (nullable = true)
#  |-- _hoodie_record_key: string (nullable = true)
#  |-- _hoodie_partition_path: string (nullable = true)
#  |-- _hoodie_file_name: string (nullable = true)
#  |-- srcode: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- grade_numeric: decimal(10,2) (nullable = true)
#  |-- career: string (nullable = true)
#  |-- uuid: long (nullable = false)

# %%
import os
from pyspark.sql.functions import current_timestamp, monotonically_increasing_id, lit

def process_program_data(program_json_path, raw_df, warehouse_path):
    """Process data for a single program and save to Hudi"""
    
    # Read the JSON file
    with open(program_json_path, "r") as f:
        course_career_json = f.read()
    
    # Get program name from file name
    program_name = os.path.basename(program_json_path).replace('.json', '')
    
    # Get the mapping
    mapping = get_course_career_mapping
    
    
    mapping(course_career_json)
    
    # Create the recommendations dataframe
    program_df = map_courses_to_careers(raw_df, mapping)
    
    # Add uuid
    program_df = program_df.withColumn("uuid", monotonically_increasing_id())
    
    # Save to Hudi
    db_name = "recommender_db"
    table_name = f"{program_name}_recommender"
    path = f"{warehouse_path}/{db_name}/{table_name}"
    
    hudi_options = {
        "hoodie.table.name": table_name,
        "hoodie.datasource.write.recordkey.field": "uuid",
        'hoodie.datasource.write.operation': 'bulk_insert',
        "hoodie.datasource.write.keygenerator.class": "org.apache.hudi.keygen.NonpartitionedKeyGenerator"
    }
    
    program_df.write.format("hudi") \
        .options(**hudi_options) \
        .mode("overwrite") \
        .save(path)
    
    return program_df

# Directory containing JSON files
json_directory = "C:/LEONAIDAS/scripts/career-mapping"

# Process each program
for json_file in os.listdir(json_directory):
    if json_file.endswith('.json'):
        program_json_path = os.path.join(json_directory, json_file)
        program_df = process_program_data(program_json_path, raw_df, warehouse_path)
        print(f"Processed {json_file}")
        program_df.show(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 52
#      50 if json_file.endswith('.json'):
#      51     program_json_path = os.path.join(json_directory, json_file)
# ---> 52     program_df = process_program_data(program_json_path, raw_df, warehouse_path)
#      53     print(f"Processed {json_file}")
#      54     program_df.show(5)
#
# NameError: name 'raw_df' is not defined
