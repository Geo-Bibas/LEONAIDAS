# %%
from pyspark.sql import SparkSession

jdbc_url = "jdbc:postgresql://192.168.20.11:5432/demo_db"
properties = {
    "user": "postgres", 
    "password": "postgres",  
    "driver": "org.postgresql.Driver",
    "fetchsize": "10000"
}

#DOWNLOAD FROM ORACLE
postgres_driver_path = "C:\postgresql-42.7.5.jar"

def extract(jdbc_url, table_name, properties, postgres_driver_path):
    """ Extract data from PostgreSQL database using Spark."""
    # Initialize Spark session
    spark = SparkSession.builder \
        .appName("Postgres Connection") \
        .config("spark.jars", postgres_driver_path) \
        .config("spark.driver.memory", "8g") \
        .config("spark.executor.memory", "8g") \
        .config("spark.executor.memoryOverhead", "2g") \
        .config("spark.driver.memoryOverhead", "2g") \
        .getOrCreate()

    # Extracts data from PostgreSQL database
    df = spark.read.jdbc(
        url=jdbc_url,
        table=table_name,
        properties=properties,
    )
    
    return df, spark

# Extract data once
raw_df, spark = extract(jdbc_url, "filtered_data_with_id", properties, postgres_driver_path)

# Check the number of rows
row_count = raw_df.count()
print(f'Number of rows: {row_count}')

# Print schema
raw_df.printSchema()
# Out:
# Number of rows: 1999679
# root
#  |-- id: integer (nullable = true)
#  |-- schoolyear: string (nullable = true)
#  |-- semester: string (nullable = true)
#  |-- code: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- credits: integer (nullable = true)
#  |-- instructor_id: string (nullable = true)
#  |-- instructor: string (nullable = true)
#  |-- srcode: string (nullable = true)
#  |-- fullname: string (nullable = true)
#  |-- campus: string (nullable = true)
#  |-- college: string (nullable = true)
#  |-- program: string (nullable = true)
#  |-- grade_final: string (nullable = true)
#  |-- grade_reexam: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- grade_numeric: decimal(5,2) (nullable = true)
#  |-- grade_classification: string (nullable = true)

# %%
from pyspark.sql.functions import col, count, max, row_number
from pyspark.sql.window import Window

def remove_previous_programs(df):
    #Remove records of previous programs for shifters.
    
    # Create a window spec partitioned by srcode ordered by schoolyear desc
    window_spec = Window.partitionBy("srcode").orderBy(col("schoolyear").desc())
    
    # Get the most recent program for each student
    latest_programs = df.withColumn("row_number", row_number().over(window_spec)) \
        .filter(col("row_number") == 1) \
        .select("srcode", "program", "schoolyear") \
        .withColumnRenamed("srcode", "latest_srcode") \
        .withColumnRenamed("program", "latest_program") \
        .withColumnRenamed("schoolyear", "latest_schoolyear")
    
    # Join with original dataframe to keep only records with the most recent program
    filtered_df = df.join(
        latest_programs,
        (df.srcode == latest_programs.latest_srcode) & 
        (df.program == latest_programs.latest_program),
        "inner"
    ).drop("latest_srcode", "latest_program", "latest_schoolyear")
    
    return filtered_df

cleaned_df = remove_previous_programs(raw_df)

# %%
from pyspark.sql.functions import split, col, trim, when

# Get distinct schoolyear values
distinct_years_df = raw_df.select("schoolyear").distinct()

# Optionally, show all distinct school years
distinct_years_df.show(truncate=False)

# Extract the starting year from the 'schoolyear' column
# Assumes format like "2021-2022"
distinct_years_df = distinct_years_df.withColumn("start_year", split(col("schoolyear"), "-")[0].cast("int"))

# Filter for school years starting from 2006 (or later)
#valid_years_df = distinct_years_df.filter(col("start_year") >= 2006)

valid_years_df = distinct_years_df.orderBy("start_year")

# Collect the valid schoolyear values as a list
valid_schoolyears = [row.schoolyear for row in valid_years_df.collect()]
print("Valid schoolyears:", valid_schoolyears)
# Out:
# +----------+
# |schoolyear|
# +----------+
# |2022-2023 |
# |2021-2022 |
# |2011-2012 |
# |2012-2013 |
# |2013-2014 |
# |2016-2017 |
# |2010-2011 |
# |2014-2015 |
# |2007-2008 |
# |2006-2007 |
# |2017-2018 |
# |2019-2020 |
# |2018-2019 |
# |2023-2024 |
# |2009-2010 |
# |2024-2025 |
# |2008-2009 |
# |2020-2021 |
# |2015-2016 |
# +----------+
#
# Valid schoolyears: ['2006-2007', '2007-2008', '2008-2009', '2009-2010', '2010-2011', '2011-2012', '2012-2013', '2013-2014', '2014-2015', '2015-2016', '2016-2017', '2017-2018', '2018-2019', '2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']

# %%
from pyspark.sql.functions import split, col, when, concat_ws

# Define the semesters you're interested in
semesters = ["FIRST", "SECOND", "SUMMER"]

# Filter the DataFrame on the valid schoolyears, semesters, and ensure grade_numeric is not null
filtered_df = cleaned_df.filter(
    (col("schoolyear").isin(valid_schoolyears)) &
    (col("semester").isin(semesters)) &
    (col("grade_numeric").isNotNull())
)

# Extract the starting year from the 'schoolyear' column (assumes format "2021-2022")
filtered_df = filtered_df.withColumn("start_year", split(col("schoolyear"), "-")[0].cast("int"))

# Create a custom order for the semester column
filtered_df = filtered_df.withColumn(
    "sem_order",
    when(col("semester") == "FIRST", 1)
    .when(col("semester") == "SECOND", 2)
    .when(col("semester") == "SUMMER", 3)
)

# Create the 'yearsem' column by concatenating schoolyear and semester (e.g., "2021-2022-FIRST")
filtered_df = filtered_df.withColumn("yearsem", concat_ws("-", col("schoolyear"), col("semester")))

# Order by start_year and then by sem_order to get FIRST, SECOND, SUMMER in that order for each year
output_df = filtered_df.select("srcode", "yearsem", "grade_numeric", "program").orderBy("srcode","start_year", "sem_order", "description")

# Show a preview of the results
output_df.show(500, truncate=False)
# Out:
# +------+----------------+-------------+------------------------------------------------------------+
# |srcode|yearsem         |grade_numeric|program                                                     |
# +------+----------------+-------------+------------------------------------------------------------+
# |100005|2020-2021-FIRST |1.00         |Master of Arts in Education major in Educational Management |
# |100005|2020-2021-FIRST |1.25         |Master of Arts in Education major in Educational Management |
# |100005|2020-2021-FIRST |1.00         |Master of Arts in Education major in Educational Management |
# |100005|2020-2021-SECOND|1.00         |Master of Arts in Education major in Educational Management |
# |100005|2020-2021-SECOND|1.00         |Master of Arts in Education major in Educational Management |
# |100005|2020-2021-SECOND|1.25         |Master of Arts in Education major in Educational Management |
# |100005|2021-2022-FIRST |1.00         |Master of Arts in Education major in Educational Management |
# |100005|2021-2022-FIRST |1.00         |Master of Arts in Education major in Educational Management |
# |100005|2021-2022-SECOND|1.00         |Master of Arts in Education major in Educational Management |
# |100005|2021-2022-SECOND|1.25         |Master of Arts in Education major in Educational Management |
# |100010|2020-2021-FIRST |2.00         |BS Hospitality Management                                   |
# |100010|2020-2021-FIRST |1.50         |BS Hospitality Management                                   |
# |100010|2020-2021-FIRST |1.50         |BS Hospitality Management                                   |
# |100010|2020-2021-FIRST |1.75         |BS Hospitality Management                                   |
# |100010|2020-2021-FIRST |2.25         |BS Hospitality Management                                   |
# |100010|2020-2021-FIRST |1.50         |BS Hospitality Management                                   |
# |100010|2020-2021-FIRST |2.50         |BS Hospitality Management                                   |
# |100010|2020-2021-FIRST |2.50         |BS Hospitality Management                                   |
# |100010|2020-2021-FIRST |2.25         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|1.50         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|1.00         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|1.75         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|1.75         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|1.75         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|2.00         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|2.00         |BS Hospitality Management                                   |
# |100010|2020-2021-SECOND|1.50         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |2.75         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |2.75         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |2.25         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |1.50         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |2.00         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |2.00         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |2.75         |BS Hospitality Management                                   |
# |100010|2021-2022-FIRST |3.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2021-2022-SECOND|5.00         |BS Hospitality Management                                   |
# |100010|2022-2023-FIRST |2.50         |BS Hospitality Management                                   |
# |100010|2022-2023-FIRST |2.25         |BS Hospitality Management                                   |
# |100010|2022-2023-FIRST |5.00         |BS Hospitality Management                                   |
# |100010|2022-2023-FIRST |2.25         |BS Hospitality Management                                   |
# |100010|2022-2023-FIRST |2.00         |BS Hospitality Management                                   |
# |100010|2022-2023-FIRST |1.75         |BS Hospitality Management                                   |
# |100010|2022-2023-FIRST |1.75         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|2.75         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|2.00         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|1.50         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|2.50         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|3.00         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|2.50         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|1.75         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|3.00         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|2.25         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|2.25         |BS Hospitality Management                                   |
# |100010|2022-2023-SECOND|2.00         |BS Hospitality Management                                   |
# |100010|2023-2024-FIRST |2.25         |BS Hospitality Management                                   |
# |100010|2023-2024-FIRST |2.25         |BS Hospitality Management                                   |
# |100010|2023-2024-FIRST |2.00         |BS Hospitality Management                                   |
# |100010|2023-2024-FIRST |3.00         |BS Hospitality Management                                   |
# |100010|2023-2024-SECOND|2.50         |BS Hospitality Management                                   |
# |100010|2023-2024-SECOND|1.50         |BS Hospitality Management                                   |
# |100010|2023-2024-SECOND|2.50         |BS Hospitality Management                                   |
# |100010|2023-2024-SECOND|3.00         |BS Hospitality Management                                   |
# |100010|2023-2024-SECOND|2.50         |BS Hospitality Management                                   |
# |100010|2023-2024-SECOND|1.75         |BS Hospitality Management                                   |
# |100010|2023-2024-SECOND|2.00         |BS Hospitality Management                                   |
# |100010|2023-2024-SUMMER|1.25         |BS Hospitality Management                                   |
# |100010|2024-2025-FIRST |2.75         |BS Hospitality Management                                   |
# |100010|2024-2025-FIRST |2.25         |BS Hospitality Management                                   |
# |100010|2024-2025-FIRST |3.00         |BS Hospitality Management                                   |
# |100010|2024-2025-FIRST |1.50         |BS Hospitality Management                                   |
# |100016|2020-2021-FIRST |1.50         |BS Psychology                                               |
# |100016|2020-2021-FIRST |1.00         |BS Psychology                                               |
# |100016|2020-2021-FIRST |1.25         |BS Psychology                                               |
# |100016|2020-2021-FIRST |1.50         |BS Psychology                                               |
# |100016|2020-2021-FIRST |1.25         |BS Psychology                                               |
# |100016|2020-2021-FIRST |1.00         |BS Psychology                                               |
# |100016|2020-2021-FIRST |1.25         |BS Psychology                                               |
# |100016|2020-2021-FIRST |1.75         |BS Psychology                                               |
# |100016|2020-2021-SECOND|2.25         |BS Psychology                                               |
# |100016|2020-2021-SECOND|2.00         |BS Psychology                                               |
# |100016|2020-2021-SECOND|2.50         |BS Psychology                                               |
# |100016|2020-2021-SECOND|1.50         |BS Psychology                                               |
# |100016|2020-2021-SECOND|1.75         |BS Psychology                                               |
# |100016|2020-2021-SECOND|2.00         |BS Psychology                                               |
# |100016|2020-2021-SECOND|1.50         |BS Psychology                                               |
# |100016|2020-2021-SECOND|1.50         |BS Psychology                                               |
# |100016|2021-2022-FIRST |3.00         |BS Psychology                                               |
# |100016|2021-2022-FIRST |2.50         |BS Psychology                                               |
# |100016|2021-2022-FIRST |1.50         |BS Psychology                                               |
# |100016|2021-2022-FIRST |1.25         |BS Psychology                                               |
# |100016|2021-2022-FIRST |5.00         |BS Psychology                                               |
# |100016|2021-2022-FIRST |2.00         |BS Psychology                                               |
# |100016|2021-2022-FIRST |1.50         |BS Psychology                                               |
# |100016|2021-2022-FIRST |1.50         |BS Psychology                                               |
# |100016|2021-2022-FIRST |2.25         |BS Psychology                                               |
# |100016|2021-2022-SECOND|5.00         |BS Psychology                                               |
# |100016|2021-2022-SECOND|2.50         |BS Psychology                                               |
# |100016|2021-2022-SECOND|2.75         |BS Psychology                                               |
# |100016|2021-2022-SECOND|2.25         |BS Psychology                                               |
# |100016|2021-2022-SECOND|2.00         |BS Psychology                                               |
|BS Agriculture                                              |
# |100243|2022-2023-FIRST |2.25         |BS Agriculture                                              |
# |100243|2022-2023-FIRST |2.75         |BS Agriculture                                              |
# |100243|2022-2023-FIRST |5.00         |BS Agriculture                                              |
# |100243|2022-2023-FIRST |1.75         |BS Agriculture                                              |
# |100243|2022-2023-FIRST |1.75         |BS Agriculture                                              |
# |100243|2022-2023-FIRST |2.25         |BS Agriculture                                              |
# |100243|2022-2023-FIRST |1.75         |BS Agriculture                                              |
# |100243|2022-2023-FIRST |1.25         |BS Agriculture                                              |
# |100243|2022-2023-FIRST |1.00         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|1.75         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|1.25         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|1.75         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|1.50         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|1.50         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|2.00         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|1.50         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|2.25         |BS Agriculture                                              |
# |100243|2022-2023-SECOND|1.75         |BS Agriculture                                              |
# |100243|2022-2023-SUMMER|1.50         |BS Agriculture                                              |
# |100243|2023-2024-FIRST |1.00         |BS Agriculture                                              |
# |100243|2023-2024-FIRST |2.00         |BS Agriculture                                              |
# |100243|2023-2024-FIRST |1.75         |BS Agriculture                                              |
# |100243|2023-2024-FIRST |1.50         |BS Agriculture                                              |
# |100243|2023-2024-FIRST |2.00         |BS Agriculture                                              |
# |100243|2023-2024-FIRST |1.75         |BS Agriculture                                              |
# |100243|2023-2024-FIRST |2.25         |BS Agriculture                                              |
# |100243|2023-2024-SECOND|2.50         |BS Agriculture                                              |
# |100243|2023-2024-SECOND|2.25         |BS Agriculture                                              |
# |100243|2024-2025-FIRST |1.25         |BS Agriculture                                              |
# |100243|2024-2025-FIRST |1.50         |BS Agriculture                                              |
# |100243|2024-2025-FIRST |2.25         |BS Agriculture                                              |
# |100243|2024-2025-FIRST |1.50         |BS Agriculture                                              |
# |100243|2024-2025-FIRST |2.50         |BS Agriculture                                              |
# |100243|2024-2025-FIRST |1.00         |BS Agriculture                                              |
# |100243|2024-2025-FIRST |3.00         |BS Agriculture                                              |
# |100243|2024-2025-FIRST |1.25         |BS Agriculture                                              |
# |100252|2021-2022-FIRST |3.00         |BS Public Health                                            |
# |100252|2021-2022-FIRST |2.00         |BS Public Health                                            |
# |100252|2021-2022-FIRST |1.50         |BS Public Health                                            |
# |100252|2021-2022-FIRST |1.25         |BS Public Health                                            |
# |100252|2021-2022-FIRST |1.25         |BS Public Health                                            |
# |100252|2021-2022-FIRST |1.25         |BS Public Health                                            |
# |100252|2021-2022-SECOND|2.25         |BS Public Health                                            |
# |100252|2021-2022-SECOND|1.50         |BS Public Health                                            |
# |100252|2021-2022-SECOND|2.00         |BS Public Health                                            |
# |100252|2021-2022-SECOND|1.75         |BS Public Health                                            |
# |100252|2021-2022-SECOND|1.50         |BS Public Health                                            |
# |100252|2021-2022-SECOND|2.75         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.25         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.00         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.25         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.50         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.25         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.50         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.00         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.50         |BS Public Health                                            |
# |100252|2022-2023-FIRST |1.25         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.25         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.25         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.25         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.00         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.00         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.25         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.25         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.25         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.50         |BS Public Health                                            |
# |100252|2022-2023-SECOND|1.25         |BS Public Health                                            |
# |100252|2023-2024-FIRST |1.75         |BS Public Health                                            |
# |100252|2023-2024-FIRST |2.25         |BS Public Health                                            |
# |100252|2023-2024-FIRST |1.00         |BS Public Health                                            |
# +------+----------------+-------------+------------------------------------------------------------+
# only showing top 500 rows

# %%
# First, read the CSV file with program mappings
program_mapping_df = spark.read.csv("C:\LEONAIDAS\program_with_id.csv", header=True)

# Convert DataFrame to dictionary with program_id as key (convert to int)
program_dict = {int(row['program_id']): row['program'] for row in program_mapping_df.collect()}

# Create a reverse dictionary for lookup
reverse_program_dict = {v: k for k, v in program_dict.items()}

# Create a mapping function
def get_program_id(program):
    return reverse_program_dict.get(program)

# Register the UDF (User Defined Function)
from pyspark.sql.functions import udf
from pyspark.sql.types import IntegerType  # Changed to IntegerType

get_program_id_udf = udf(get_program_id, IntegerType())

# Add the new column to your DataFrame
output_df = output_df.withColumn("program_id", get_program_id_udf(col("program")))

# Show the results
output_df.select("srcode", "yearsem", "grade_numeric", "program", "program_id").show(5)

# Optionally verify the mapping
output_df.groupBy("program", "program_id").count().orderBy("program_id").show(500, truncate=False)
# Out:
# +------+----------------+-------------+--------------------+----------+
# |srcode|         yearsem|grade_numeric|             program|program_id|
# +------+----------------+-------------+--------------------+----------+
# |100005| 2020-2021-FIRST|         1.00|Master of Arts in...|        98|
# |100005| 2020-2021-FIRST|         1.25|Master of Arts in...|        98|
# |100005| 2020-2021-FIRST|         1.00|Master of Arts in...|        98|
# |100005|2020-2021-SECOND|         1.00|Master of Arts in...|        98|
# |100005|2020-2021-SECOND|         1.00|Master of Arts in...|        98|
# +------+----------------+-------------+--------------------+----------+
# only showing top 5 rows
#
# +---------------------------------------------------------------------------------+----------+------+
# |program                                                                          |program_id|count |
# +---------------------------------------------------------------------------------+----------+------+
# |Master of Arts in Education major in Filipino                                    |null      |14    |
# |Bachelor of Arts  in Communication                                               |1         |44219 |
# |Bachelor of Arts in English Language Studies                                     |2         |16371 |
# |Bachelor of Automotive Engineering Technology                                    |3         |1851  |
# |Bachelor of Civil Engineering Technology                                         |4         |1602  |
# |Bachelor of Computer Engineering Technology                                      |5         |3364  |
# |Bachelor of Drafting Engineering Technology                                      |6         |1136  |
# |Bachelor of Early Childhood Education                                            |7         |4640  |
# |Bachelor of Electrical Engineering Technology                                    |8         |2377  |
# |Bachelor of Electronics Engineering Technology                                   |9         |1060  |
# |Bachelor of Elementary Education                                                 |10        |27943 |
# |Bachelor of Fine Arts and Design                                                 |11        |7989  |
# |Bachelor of Food Engineering Technology                                          |12        |1105  |
# |Bachelor of Industrial Technology                                                |13        |144283|
# |Bachelor of Instrumentation and Control Engineering Technology                   |14        |1541  |
# |Bachelor of Laws                                                                 |15        |2265  |
# |Bachelor of Mechanical Engineering Technology                                    |16        |1644  |
# |Bachelor of Mechatronics Engineering Technology                                  |17        |505   |
# |Bachelor of Physical Education                                                   |18        |16060 |
# |Bachelor of Public Administration                                                |19        |49263 |
# |Bachelor of Secondary Education                                                  |20        |125751|
# |Bachelor of Technical-Vocational Teacher Education                               |21        |4425  |
# |Bachelor of Technology and Livelihood Education                                  |22        |11759 |
# |Bachelor of Welding and Fabrication Engineering Technology                       |23        |571   |
# |BS Accountancy                                                                   |24        |17558 |
# |BS Accounting Management                                                         |25        |72    |
# |BS Aerospace Engineering                                                         |26        |17340 |
# |BS Agriculture                                                                   |27        |9640  |
# |BS Architecture                                                                  |28        |79318 |
# |BS Automotive Engineering                                                        |29        |3973  |
# |BS Biology                                                                       |30        |12088 |
# |BS Biomedical Engineering                                                        |31        |3366  |
# |BS Business Administration                                                       |32        |192208|
# |BS Ceramics Engineering                                                          |33        |2615  |
# |BS Chemical Engineering                                                          |34        |37872 |
# |BS Chemistry                                                                     |35        |3453  |
# |BS Civil Engineering                                                             |36        |76076 |
# |BS Computer Engineering                                                          |37        |29533 |
# |BS Computer Science                                                              |38        |12077 |
# |BS Criminology                                                                   |39        |69794 |
# |BS Customs Administration                                                        |40        |19332 |
# |BS Development Communication                                                     |41        |16248 |
# |BS Electrical Engineering                                                        |42        |40241 |
# |BS Electronics Engineering                                                       |43        |25214 |
# |BS Entrepreneurship                                                              |44        |9248  |
# |BS Fisheries and Aquatic Sciences                                                |45        |10032 |
# |BS Food Engineering                                                              |46        |11025 |
# |BS Food Technology                                                               |47        |989   |
# |BS Forestry                                                                      |48        |2883  |
# |BS Geodetic Engineering                                                          |49        |8047  |
# |BS Geological Engineering                                                        |50        |6381  |
# |BS Hospitality Management                                                        |51        |78759 |
# |BS Industrial Engineering                                                        |52        |39880 |
# |BS Information Technology                                                        |53        |125101|
# |BS Instrumentation and Control Engineering                                       |54        |23859 |
# |BS Interior Design                                                               |55        |6192  |
# |BS Management Accounting                                                         |56        |65518 |
# |BS Mathematics                                                                   |57        |1805  |
# |BS Mechanical Engineering                                                        |58        |93622 |
# |BS Mechatronics Engineering                                                      |59        |12573 |
# |BS Metallurgical Engineering                                                     |60        |5617  |
# |BS Naval Architecture and Marine Engineering                                     |61        |6889  |
# |BS Nursing                                                                       |62        |72559 |
# |BS Nutrition and Dietetics                                                       |63        |17360 |
# |BS Petroleum Engineering                                                         |64        |30712 |
# |BS Psychology                                                                    |65        |78175 |
# |BS Public Health                                                                 |66        |5015  |
# |BS Sanitary Engineering                                                          |67        |18897 |
# |BS Tourism Management                                                            |68        |58932 |
# |BS Transportation Engineering                                                    |69        |4572  |
# |Doctor in Business Administration                                                |70        |257   |
# |Doctor in Public Administration                                                  |71        |133   |
# |Doctor of Education major in Educational Management                              |72        |672   |
# |Doctor of Medicine                                                               |73        |1537  |
# |Doctor of Philosophy in Electronics Engineering                                  |74        |198   |
# |Doctor of Philosophy in Engineering Education                                    |75        |191   |
# |Doctor of Philosophy in Engineering Management                                   |76        |108   |
# |Doctor of Philosophy in English                                                  |77        |451   |
# |Doctor of Philosophy major in Educational Management                             |78        |1235  |
# |Doctor of Philosophy major in English                                            |79        |19    |
# |Doctor of Philosophy major in Mathematics Education                              |80        |697   |
# |Doctor of Technology                                                             |81        |265   |
# |Juris Doctor                                                                     |88        |961   |
# |Master in Business Administration                                                |89        |927   |
# |Master in Chemistry                                                              |90        |60    |
# |Master in Disaster Risk Management                                               |91        |281   |
# |Master in Information Technology                                                 |92        |243   |
# |Master in Public Administration                                                  |94        |211   |
# |Master in Supply Chain Management                                                |95        |184   |
# |Master in Urban Planning and Design                                              |96        |363   |
# |Master of Arts in Development Studies                                            |97        |94    |
# |Master of Arts in Education major in Educational Management                      |98        |749   |
# |Master of Arts in Education major in English Language Teaching                   |99        |1073  |
# |Master of Arts in Education major in Mathematics Teaching                        |100       |533   |
# |Master of Arts in Education major in Pagtuturo ng Filipino                       |101       |434   |
# |Master of Arts in Education major in Physical Education                          |102       |213   |
# |Master of Arts in Education major in Psychology                                  |103       |100   |
# |Master of Arts in Education major in Science Teaching                            |104       |432   |
# |Master of Arts in Education major in Social Studies Teaching                     |105       |373   |
# |Master of Arts in Education major in Technology and Livelihood Education Teaching|106       |545   |
# |Master of Arts in English                                                        |107       |68    |
# |Master of Development Communication                                              |108       |125   |
# |Master of Engineering                                                            |109       |525   |
# |Master of Science in Advanced Manufacturing                                      |110       |20    |
# |Master of Science in Artificial Intelligence                                     |111       |39    |
# |Master of Science in Computer Engineering                                        |112       |108   |
# |Master of Science in Computer Science                                            |113       |73    |
# |Master of Science in Construction Management                                     |114       |209   |
# |Master of Science in Data Science                                                |115       |105   |
# |Master of Science in Earthquake Engineering                                      |116       |26    |
# |Master of Science in Electronics Engineering                                     |117       |50    |
# |Master of Science in Energy Engineering                                          |118       |94    |
# |Master of Science in Engineering Management                                      |119       |236   |
# |Master of Science in Information Technology                                      |120       |27    |
# |Master of Science in Marine Biology                                              |121       |11    |
# |Master of Science in Material Science and Engineering                            |122       |26    |
# |Master of Science in Mathematics                                                 |123       |32    |
# |Master of Technology                                                             |124       |197   |
# |Professional Subjects                                                            |126       |12    |
# |Straight Master's-Doctoral in Electronics Engineering                            |128       |172   |
# +---------------------------------------------------------------------------------+----------+------+

# %%
program_dict[101] = ["Master of Arts in Education major in Pagtuturo ng Filipino", "Master of Arts in Education major in Filipino"]
program_dict
# Out:
# {1: 'Bachelor of Arts  in Communication',
#  2: 'Bachelor of Arts in English Language Studies',
#  3: 'Bachelor of Automotive Engineering Technology',
#  4: 'Bachelor of Civil Engineering Technology',
#  5: 'Bachelor of Computer Engineering Technology',
#  6: 'Bachelor of Drafting Engineering Technology',
#  7: 'Bachelor of Early Childhood Education',
#  8: 'Bachelor of Electrical Engineering Technology',
#  9: 'Bachelor of Electronics Engineering Technology',
#  10: 'Bachelor of Elementary Education',
#  11: 'Bachelor of Fine Arts and Design',
#  12: 'Bachelor of Food Engineering Technology',
#  13: 'Bachelor of Industrial Technology',
#  14: 'Bachelor of Instrumentation and Control Engineering Technology',
#  15: 'Bachelor of Laws',
#  16: 'Bachelor of Mechanical Engineering Technology',
#  17: 'Bachelor of Mechatronics Engineering Technology',
#  18: 'Bachelor of Physical Education',
#  19: 'Bachelor of Public Administration',
#  20: 'Bachelor of Secondary Education',
#  21: 'Bachelor of Technical-Vocational Teacher Education',
#  22: 'Bachelor of Technology and Livelihood Education',
#  23: 'Bachelor of Welding and Fabrication Engineering Technology',
#  24: 'BS Accountancy',
#  25: 'BS Accounting Management',
#  26: 'BS Aerospace Engineering',
#  27: 'BS Agriculture',
#  28: 'BS Architecture',
#  29: 'BS Automotive Engineering',
#  30: 'BS Biology',
#  31: 'BS Biomedical Engineering',
#  32: 'BS Business Administration',
#  33: 'BS Ceramics Engineering',
#  34: 'BS Chemical Engineering',
#  35: 'BS Chemistry',
#  36: 'BS Civil Engineering',
#  37: 'BS Computer Engineering',
#  38: 'BS Computer Science',
#  39: 'BS Criminology',
#  40: 'BS Customs Administration',
#  41: 'BS Development Communication',
#  42: 'BS Electrical Engineering',
#  43: 'BS Electronics Engineering',
#  44: 'BS Entrepreneurship',
#  45: 'BS Fisheries and Aquatic Sciences',
#  46: 'BS Food Engineering',
#  47: 'BS Food Technology',
#  48: 'BS Forestry',
#  49: 'BS Geodetic Engineering',
#  50: 'BS Geological Engineering',
#  51: 'BS Hospitality Management',
#  52: 'BS Industrial Engineering',
#  53: 'BS Information Technology',
#  54: 'BS Instrumentation and Control Engineering',
#  55: 'BS Interior Design',
#  56: 'BS Management Accounting',
#  57: 'BS Mathematics',
#  58: 'BS Mechanical Engineering',
#  59: 'BS Mechatronics Engineering',
#  60: 'BS Metallurgical Engineering',
#  61: 'BS Naval Architecture and Marine Engineering',
#  62: 'BS Nursing',
#  63: 'BS Nutrition and Dietetics',
#  64: 'BS Petroleum Engineering',
#  65: 'BS Psychology',
#  66: 'BS Public Health',
#  67: 'BS Sanitary Engineering',
#  68: 'BS Tourism Management',
#  69: 'BS Transportation Engineering',
#  70: 'Doctor in Business Administration',
#  71: 'Doctor in Public Administration',
#  72: 'Doctor of Education major in Educational Management',
#  73: 'Doctor of Medicine',
#  74: 'Doctor of Philosophy in Electronics Engineering',
#  75: 'Doctor of Philosophy in Engineering Education',
#  76: 'Doctor of Philosophy in Engineering Management',
#  77: 'Doctor of Philosophy in English',
#  78: 'Doctor of Philosophy major in Educational Management',
#  79: 'Doctor of Philosophy major in English',
#  80: 'Doctor of Philosophy major in Mathematics Education',
#  81: 'Doctor of Technology',
#  82: 'Elementary',
#  83: 'ETEEAP - Bachelor of Industrial Technology',
#  84: 'ETEEAP - BS Computer Engineering',
#  85: 'ETEEAP - BS Industrial Engineering',
#  86: 'ETEEAP - BS Information Technology',
#  87: 'Junior High School',
#  88: 'Juris Doctor',
#  89: 'Master in Business Administration',
#  90: 'Master in Chemistry',
#  91: 'Master in Disaster Risk Management',
#  92: 'Master in Information Technology',
#  93: 'Master in Port Management',
#  94: 'Master in Public Administration',
#  95: 'Master in Supply Chain Management',
#  96: 'Master in Urban Planning and Design ',
#  97: 'Master of Arts in Development Studies',
#  98: 'Master of Arts in Education major in Educational Management',
#  99: 'Master of Arts in Education major in English Language Teaching',
#  100: 'Master of Arts in Education major in Mathematics Teaching',
#  101: 'Master of Arts in Education major in Pagtuturo ng Filipino',
#  102: 'Master of Arts in Education major in Physical Education',
#  103: 'Master of Arts in Education major in Psychology',
#  104: 'Master of Arts in Education major in Science Teaching',
#  105: 'Master of Arts in Education major in Social Studies Teaching',
#  106: 'Master of Arts in Education major in Technology and Livelihood Education Teaching',
#  107: 'Master of Arts in English',
#  108: 'Master of Development Communication',
#  109: 'Master of Engineering',
#  110: 'Master of Science in Advanced Manufacturing',
#  111: 'Master of Science in Artificial Intelligence',
#  112: 'Master of Science in Computer Engineering',
#  113: 'Master of Science in Computer Science',
#  114: 'Master of Science in Construction Management',
#  115: 'Master of Science in Data Science',
#  116: 'Master of Science in Earthquake Engineering',
#  117: 'Master of Science in Electronics Engineering',
#  118: 'Master of Science in Energy Engineering',
#  119: 'Master of Science in Engineering Management',
#  120: 'Master of Science in Information Technology',
#  121: 'Master of Science in Marine Biology',
#  122: 'Master of Science in Material Science and Engineering',
#  123: 'Master of Science in Mathematics',
#  124: 'Master of Technology',
#  125: 'Pre-Elementary',
#  126: 'Professional Subjects',
#  127: 'Senior High School',
#  128: "Straight Master's-Doctoral in Electronics Engineering"}
